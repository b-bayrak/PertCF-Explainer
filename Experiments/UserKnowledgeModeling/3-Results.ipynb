# %%
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

warnings.filterwarnings("ignore")

# %% [markdown]
# -----

# %%
res_list_names = ['coef', 'num_iter', 'dissimilarity', 'sparsity', 'instability', 'time']
num_iter = [2,3,4,5,10,20,50]

df = pd.DataFrame([],columns=res_list_names) 

for i in num_iter:
    df = df.append(pd.read_pickle('./Output/exp1_coef_1-750_numIter_'+ str(i) +'.pkl'))

df.reset_index(inplace=True)
df=df.drop(['index'],axis=1)

# %%
sns.set_style("ticks")
sns.set_context("poster")

sns.lineplot(x = "coef", y = "dissimilarity", data = df, style = "num_iter", hue = "num_iter", palette = 'Paired')
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)

plt.savefig('./Output/img/dissimilarity-coef.png', dpi=1200, bbox_inches='tight')

# %%
sns.set_style("ticks")
sns.set_context("poster")

sns.lineplot(x = "coef", y = "dissimilarity", data = df[(df.coef <= 50)], style = "num_iter", hue = "num_iter", palette = 'Paired')
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)

plt.savefig('./Output/img/dissimilarity-coef_50.png', dpi=1200, bbox_inches='tight')

# %%
sns.set_style("ticks")
sns.set_context("poster")

sns.lineplot(x = "coef", y = "dissimilarity", data = df[(df.coef <= 50)], style = "num_iter", hue = "num_iter", palette = 'Paired')
plt.legend(bbox_to_anchor=(1.02, 1.2), loc='upper center', borderaxespad=0, ncol=7)

# %%
sns.set_style("ticks")
sns.set_context("poster")

sns.lineplot(x = "coef", y = "sparsity", data = df, style = "num_iter", hue = "num_iter", palette = 'Paired')
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)

plt.savefig('./Output/img/sparsity-coef.png', dpi=1200, bbox_inches='tight')

# %%
sns.set_style("ticks")
sns.set_context("poster")

sns.lineplot(x = "coef", y = "sparsity", data = df[(df.coef <= 50)], style = "num_iter", hue = "num_iter", palette = 'Paired')
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)

plt.savefig('./Output/img/sparsity-coef_50.png', dpi=1200, bbox_inches='tight')

# %%
sns.set_style("ticks")
sns.set_context("poster")

sns.lineplot(x = "coef", y = "instability", data = df, style = "num_iter", hue = "num_iter", palette = 'Paired')
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)

plt.savefig('./Output/img/instability-coef.png', dpi=1200, bbox_inches='tight')

# %%
sns.set_style("ticks")
sns.set_context("poster")

sns.lineplot(x = "coef", y = "instability", data = df[(df.coef <= 50)], style = "num_iter", hue = "num_iter", palette = 'Paired')
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)

plt.savefig('./Output/img/instability-coef_50.png', dpi=1200, bbox_inches='tight')

# %%
sns.set_style("ticks")
sns.set_context("poster")

sns.lineplot(x = "coef", y = "time", data = df, style = "num_iter", hue = "num_iter", palette = 'Paired')
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)

plt.savefig('./Output/img/time-coef.png', dpi=1200, bbox_inches='tight')

# %%
sns.set_style("ticks")
sns.set_context("poster")

sns.lineplot(x = "coef", y = "time", data = df[(df.coef <= 50)], style = "num_iter", hue = "num_iter", palette = 'Paired')
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)

plt.savefig('./Output/img/time-coef_50.png', dpi=1200, bbox_inches='tight')
